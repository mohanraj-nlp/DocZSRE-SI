# %% [markdown]
# # Similarity based Prediction

# %%
import json
import torch
import numpy as np
import evaluation as eval
from collections import Counter
from transformers import BertModel, BertTokenizer

# %% [markdown]
# # Inference

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
with open("./MEN-Dataset_Results/only_descriptions_and_hypernym.json", "r") as f:
    data = json.load(f)

# MORE THAN EQUAL 5 DOCRED ONLY
unseen_relation_labels = ['given name', 'capital of', 'operator', 'director / manager', 'country of citizenship']

# %%
data[0]
# Out:
# {'id': 'article_1',
#  'entities': [{'id': 1,
#    'label': 'TITLE',
#    'position': {'start_offset': 893, 'end_offset': 895}},
#   {'id': 2,
#    'label': 'PERSON',
#    'position': {'start_offset': 116, 'end_offset': 139}},
#   {'id': 3,
#    'label': 'LOCATION',
#    'position': {'start_offset': 0, 'end_offset': 12}},
#   {'id': 4,
#    'label': 'LOCATION',
#    'position': {'start_offset': 14, 'end_offset': 22}},
#   {'id': 5,
#    'label': 'EVENT',
#    'position': {'start_offset': 625, 'end_offset': 633}},
#   {'id': 6,
#    'label': 'PERSON',
#    'position': {'start_offset': 108, 'end_offset': 139}},
#   {'id': 7,
#    'label': 'PERSON',
#    'position': {'start_offset': 91, 'end_offset': 139}},
#   {'id': 8,
#    'label': 'PERSON',
#    'position': {'start_offset': 119, 'end_offset': 139}},
#   {'id': 9,
#    'label': 'PERSON',
#    'position': {'start_offset': 651, 'end_offset': 665}},
#   {'id': 10,
#    'label': 'PERSON',
#    'position': {'start_offset': 654, 'end_offset': 665}},
#   {'id': 11,
#    'label': 'PERSON',
#    'position': {'start_offset': 893, 'end_offset': 907}},
#   {'id': 12,
#    'label': 'PERSON',
#    'position': {'start_offset': 896, 'end_offset': 907}},
#   {'id': 13,
#    'label': 'ORGANIZATION',
#    'position': {'start_offset': 917, 'end_offset': 932}},
#   {'id': 14,
#    'label': 'PERSON',
#    'position': {'start_offset': 1080, 'end_offset': 1094}},
#   {'id': 15,
#    'label': 'PERSON',
#    'position': {'start_offset': 1083, 'end_offset': 1094}},
#   {'id': 16,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1256, 'end_offset': 1262}},
#   {'id': 17,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1307, 'end_offset': 1314}},
#   {'id': 18,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1323, 'end_offset': 1328}},
#   {'id': 19,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1337, 'end_offset': 1343}},
#   {'id': 20,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1352, 'end_offset': 1358}},
#   {'id': 21,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1367, 'end_offset': 1372}},
#   {'id': 22,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1381, 'end_offset': 1387}},
#   {'id': 23,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1396, 'end_offset': 1404}},
#   {'id': 24,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1409, 'end_offset': 1417}},
#   {'id': 25,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1496, 'end_offset': 1502}},
#   {'id': 26,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1426, 'end_offset': 1436}},
#   {'id': 27,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1441, 'end_offset': 1446}},
#   {'id': 28,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1455, 'end_offset': 1464}},
#   {'id': 29,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1473, 'end_offset': 1487}},
#   {'id': 30,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1511, 'end_offset': 1516}},
#   {'id': 31,
#    'label': 'LOCATION',
#    'position': {'start_offset': 1528, 'end_offset': 1540}},
#   {'id': 32,
#    'label': 'TITLE',
#    'position': {'start_offset': 108, 'end_offset': 115}},
#   {'id': 33,
#    'label': 'TITLE',
#    'position': {'start_offset': 116, 'end_offset': 118}},
#   {'id': 34,
#    'label': 'TITLE',
#    'position': {'start_offset': 651, 'end_offset': 653}},
#   {'id': 35,
#    'label': 'ROLE',
#    'position': {'start_offset': 91, 'end_offset': 107}},
#   {'id': 36,
#    'label': 'TITLE',
#    'position': {'start_offset': 1080, 'end_offset': 1082}}],
#  'relations': [{'id': 1,
#    'head': 6,
#    'tail': 35,
#    'relation': 'director',
#    'relation_source': 'DocRED'},
#   {'id': 2,
#    'head': 10,
#    'tail': 34,
#    'relation': 'award received',
#    'relation_source': 'DocRED'},
#   {'id': 3,
#    'head': 4,
#    'tail': 3,
#    'relation': 'location',
#    'relation_source': 'DocRED'},
#   {'id': 4,
#    'head': 15,
#    'tail': 36,
#    'relation': 'award received',
#    'relation_source': 'DocRED'},
#   {'id': 5,
#    'head': 33,
#    'tail': 8,
#    'relation': 'award received',
#    'relation_source': 'DocRED'},
#   {'id': 6,
#    'head': 2,
#    'tail': 32,
#    'relation': 'award received',
#    'relation_source': 'DocRED'},
#   {'id': 7,
#    'head': 13,
#    'tail': 7,
#    'relation': 'Org-Aff.Employment',
#    'relation_source': 'ACE05'},
#   {'id': 8,
#    'head': 1,
#    'tail': 12,
#    'relation': 'award received',
#    'relation_source': 'DocRED'},
#   {'id': 9,
#    'head': 14,
#    'tail': 6,
#    'relation': 'given name',
#    'relation_source': 'DocRED'},
#   {'id': 10,
#    'head': 11,
#    'tail': 6,
#    'relation': 'given name',
#    'relation_source': 'DocRED'},
#   {'id': 11,
#    'head': 11,
#    'tail': 13,
#    'relation': 'Org-Aff.Employment',
#    'relation_source': 'ACE05'},
#   {'id': 12,
#    'head': 4,
#    'tail': 5,
#    'relation': 'significant event',
#    'relation_source': 'DocRED'}],
#  'text': "KUALA LUMPUR: Malaysia logged another 21,072 Covid-19 infections as of noon today.  Health director-general Tan Sri Dr Noor Hisham Abdullah said of the fresh cases recorded today, 86 (or 0.41 per cent) were in Categories 3, 4 and 5.  In Category 5, there were eight cases (0.04 per cent); Category 4 with 20 cases (0.09 per cent), and Category 3 with 58 (0.28per cent).  Category 1 recorded 5,995 cases (28.45 per cent), while Category 2 recorded 14,991 (71.14 per cent), as both categories registered 99.59 per cent of today's total case load.  The country to date has reported a total of 3,040,235 Covid-19 cases since the pandemic struck in 2020.  Dr Noor Hisham 21,007 cases today were local transmissions while the remaining 65 cases were imported.  He added that currently 187 individuals were receiving treatment at intensive care units (ICU) and 109 cases were on ventilator support.  Dr Noor Hisham said the Health Ministry had also detected the emergence of 10 new Covid-19 clusters over the past 24 hours, making it 421 active Covid-19 clusters nationwide.  Meanwhile, Dr Noor Hisham said 5,724 more individuals had recovered from their Covid-19 infection today.  At the same time, the nationwide infectivity rate stood at 1.49 as of Saturday.  Labuan recorded the highest with 2.14, followed by Sarawak (1.67), Sabah (1.66), Perlis (1.47), Penang (1.46), Johor (1.40), Pahang (1.38), Kelantan and Selangor (1.37), Terengganu and Kedah (1.35), Putrajaya (1.34), Negri Sembilan (1.31), Melaka (1.28), Perak (1.27) and Kuala Lumpur (1.22).",
#  'unique_entity_side_information': [{'entity_mention': 'Dr',
#    'entity_type': 'TITLE',
#    'description': "Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for reporting and overseeing the country's response to Covid-19 infections.",
#    'hypernym_llm': 'Medical Title'},
#   {'entity_mention': 'Dr Noor Hisham Abdullah',
#    'entity_type': 'PERSON',
#    'description': "Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for overseeing the country's response to the Covid-19 pandemic and providing updates on infection rates and health measures.",
#    'hypernym_llm': 'Public Health Official'},
#   {'entity_mention': 'KUALA LUMPUR',
#    'entity_type': 'LOCATION',
#    'description': "Kuala Lumpur, the capital city of Malaysia, is currently experiencing a surge in Covid-19 cases, contributing to the nation's ongoing pandemic response efforts.",
#    'hypernym_llm': 'capital city'},
#   {'entity_mention': 'Malaysia',
#    'entity_type': 'LOCATION',
#    'description': 'Malaysia is currently facing a significant surge in Covid-19 cases, with over 21,000 new infections reported in a single day, highlighting ongoing public health challenges amid the pandemic.',
#    'hypernym_llm': 'Country'},
#   {'entity_mention': 'pandemic',
#    'entity_type': 'EVENT',
#    'description': 'The Covid-19 pandemic, which began in 2020, continues to impact Malaysia with a significant number of new infections, hospitalizations, and emerging clusters, as reported by health officials.',
#    'hypernym_llm': 'public health crisis'},
#   {'entity_mention': 'Tan Sri Dr Noor Hisham Abdullah',
#    'entity_type': 'PERSON',
#    'description': "Tan Sri Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for reporting and managing the country's Covid-19 response during the pandemic.",
#    'hypernym_llm': 'government official'},
#   {'entity_mention': 'director-general Tan Sri Dr Noor Hisham Abdullah',
#    'entity_type': 'PERSON',
#    'description': "Tan Sri Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for overseeing and reporting on the country's Covid-19 pandemic response and case statistics.",
#    'hypernym_llm': 'public health official'},
#   {'entity_mention': 'Noor Hisham Abdullah',
#    'entity_type': 'PERSON',
#    'description': "Tan Sri Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for providing updates and guidance on the country's Covid-19 situation amidst the pandemic.",
#    'hypernym_llm': 'Public Health Official'},
#   {'entity_mention': 'Dr Noor Hisham',
#    'entity_type': 'PERSON',
#    'description': "Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for overseeing the country's response to the Covid-19 pandemic and providing critical updates on infection rates and health measures.",
#    'hypernym_llm': 'Public Health Official'},
#   {'entity_mention': 'Noor Hisham',
#    'entity_type': 'PERSON',
#    'description': "Tan Sri Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for reporting and managing the country's Covid-19 response amidst rising infection rates.",
#    'hypernym_llm': 'Public Health Official'},
#   {'entity_mention': 'Health Ministry',
#    'entity_type': 'ORGANIZATION',
#    'description': 'The Health Ministry of Malaysia is responsible for managing public health policies and responses, particularly in the ongoing Covid-19 pandemic, as evidenced by the recent reporting of new infections and recovery rates.',
#    'hypernym_llm': 'Government Agency'},
#   {'entity_mention': 'Labuan',
#    'entity_type': 'LOCATION',
#    'description': 'Labuan is a federal territory of Malaysia that has recently been highlighted for having the highest Covid-19 infectivity rate in the country, recorded at 2.14.',
#    'hypernym_llm': 'Federal Territory'},
#   {'entity_mention': 'Sarawak',
#    'entity_type': 'LOCATION',
#    'description': 'Sarawak is a Malaysian state that is currently experiencing a notable Covid-19 infectivity rate of 1.67, indicating ongoing challenges in managing the pandemic.',
#    'hypernym_llm': 'Malaysian state'},
#   {'entity_mention': 'Sabah',
#    'entity_type': 'LOCATION',
#    'description': 'Sabah is a Malaysian state that is currently experiencing a significant Covid-19 infectivity rate of 1.66, contributing to the ongoing pandemic situation in the country.',
#    'hypernym_llm': 'Malaysian state'},
#   {'entity_mention': 'Perlis',
#    'entity_type': 'LOCATION',
#    'description': 'Perlis is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.47, indicating a significant level of transmission in the region.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Penang',
#    'entity_type': 'LOCATION',
#    'description': 'Penang is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.46, highlighting its ongoing challenges in managing the pandemic.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Johor',
#    'entity_type': 'LOCATION',
#    'description': 'Johor is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.40, reflecting its role in the ongoing pandemic situation in the country.',
#    'hypernym_llm': 'Malaysian state'},
#   {'entity_mention': 'Pahang',
#    'entity_type': 'LOCATION',
#    'description': 'Pahang is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.38, reflecting its ongoing challenges amid the pandemic.',
#    'hypernym_llm': 'Geographical Region'},
#   {'entity_mention': 'Kelantan',
#    'entity_type': 'LOCATION',
#    'description': 'Kelantan is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.37, indicating its ongoing challenges related to the pandemic.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Selangor',
#    'entity_type': 'LOCATION',
#    'description': 'Selangor is a state in Malaysia that is currently experiencing significant Covid-19 infections, contributing to the nationwide case load amid the ongoing pandemic.',
#    'hypernym_llm': 'Geopolitical region'},
#   {'entity_mention': 'Melaka',
#    'entity_type': 'LOCATION',
#    'description': 'Melaka is a state in Malaysia currently experiencing a Covid-19 infectivity rate of 1.28, indicating its ongoing challenges in managing the pandemic.',
#    'hypernym_llm': 'State'},
#   {'entity_mention': 'Terengganu',
#    'entity_type': 'LOCATION',
#    'description': 'Terengganu is a state in Malaysia that has been reported to have an infectivity rate of 1.35 amid the ongoing Covid-19 pandemic.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Kedah',
#    'entity_type': 'LOCATION',
#    'description': 'Kedah is a state in Malaysia that is currently experiencing a moderate infectivity rate of 1.35 amid the ongoing Covid-19 pandemic.',
#    'hypernym_llm': 'geographical region'},
#   {'entity_mention': 'Putrajaya',
#    'entity_type': 'LOCATION',
#    'description': 'Putrajaya is a federal territory in Malaysia, serving as the administrative center of the government and recently reported an infectivity rate of 1.34 amid the ongoing Covid-19 pandemic.',
#    'hypernym_llm': 'administrative center'},
#   {'entity_mention': 'Negri Sembilan',
#    'entity_type': 'LOCATION',
#    'description': 'Negri Sembilan is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.31, indicating its ongoing challenges with the pandemic amidst the national effort to manage and control the virus.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Perak',
#    'entity_type': 'LOCATION',
#    'description': 'Perak is a state in Malaysia that is currently experiencing a Covid-19 infectivity rate of 1.27, indicating ongoing challenges in managing the pandemic within its borders.',
#    'hypernym_llm': 'state'},
#   {'entity_mention': 'Kuala Lumpur',
#    'entity_type': 'LOCATION',
#    'description': 'Kuala Lumpur, the capital city of Malaysia, is currently grappling with a significant number of Covid-19 cases amidst the ongoing pandemic, reflecting broader national health challenges.',
#    'hypernym_llm': 'Capital City'},
#   {'entity_mention': 'Tan Sri',
#    'entity_type': 'TITLE',
#    'description': 'Tan Sri Dr Noor Hisham Abdullah is the Health Director-General of Malaysia, responsible for providing updates on the Covid-19 situation in the country.',
#    'hypernym_llm': 'Honorary Title'},
#   {'entity_mention': 'director-general',
#    'entity_type': 'ROLE',
#    'description': "The director-general of health in Malaysia, Tan Sri Dr Noor Hisham Abdullah, plays a crucial role in managing and reporting the country's Covid-19 response and statistics, including case classifications and the emergence of new clusters.",
#    'hypernym_llm': 'executive official'}]}

# %%
unseen_relation_labels
# Out:
# ['given name',
#  'capital of',
#  'operator',
#  'director / manager',
#  'country of citizenship']

# %%
data_to_test = []
rel_count = 0
unseen_relation_count_dict = {}

for item in data:
    for rel in item['relations']:
        rel_count=rel_count+1
        if rel['relation'] in unseen_relation_labels:
            head_id = rel["head"]
            tail_id = rel["tail"]
            head_obj = [ent for ent in item['entities'] if ent["id"]==head_id][0]
            tail_obj = [ent for ent in item['entities'] if ent["id"]==tail_id][0]
            head_mention = item['text'][head_obj["position"]['start_offset']:head_obj["position"]['end_offset']].strip()
            tail_mention = item['text'][tail_obj["position"]['start_offset']:tail_obj["position"]['end_offset']].strip()
            head_side_information = [ent_s for ent_s in item['unique_entity_side_information'] if ent_s['entity_mention'].lower()==head_mention.lower()][0]
            tail_side_information = [ent_s for ent_s in item['unique_entity_side_information'] if ent_s['entity_mention'].lower()==tail_mention.lower()][0]
            data_to_test.append(
                {
                    "text": item["text"],
                    "head_side_information": head_side_information,
                    "tail_side_information": tail_side_information,
                    "relation": rel["relation"]
                }
            )
            if rel["relation"] in unseen_relation_count_dict:
                unseen_relation_count_dict[rel["relation"]] = unseen_relation_count_dict[rel["relation"]]+1
            else:
                unseen_relation_count_dict[rel["relation"]] = 0
                unseen_relation_count_dict[rel["relation"]] = unseen_relation_count_dict[rel["relation"]]+1

# %%
print(rel_count)
# Out:
# 7776

# %%
# Load the pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# C:\Users\mcha0133\Desktop\Dynamic Relation Extraction (DRE)\My Solution\pykeen_only\lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def generate_embedding(text, model, tokenizer):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze()
    return embeddings

def cosine_similarity(embedding_a, embedding_b):
    return np.dot(embedding_a, embedding_b) / (np.linalg.norm(embedding_a) * np.linalg.norm(embedding_b))

# %%
def calculate_confidence(similarities):
    """
    Calculate confidence score based on consistency of different similarity measures
    """
    similarities = np.array(similarities)
    
    # Calculate mean and standard deviation
    mean_sim = np.mean(similarities)
    std_sim = np.std(similarities)
    
    # Higher confidence if similarities are consistent (low std dev) and high mean
    consistency = 1 / (1 + std_sim)  # Inverse of standard deviation
    confidence = (mean_sim + consistency) / 2
    
    return confidence

# %%
def predict_unseen_relation(head, tail, model, tokenizer, unseen_labels):
    """
    Enhanced unseen relation prediction with dynamic weighting and semantic role analysis
    """

    combined_description = head['description'] + " " + tail['description']
    head_hypernym = head['hypernym_llm']
    tail_hypernym = tail['hypernym_llm']
    head_type = head['entity_type']
    tail_type = tail['entity_type']
    
    unseen_scores = []
    
    # Generate base embeddings
    description_embedding = generate_embedding(combined_description, model, tokenizer)
    head_hypernym_embedding = generate_embedding(head_hypernym, model, tokenizer)
    tail_hypernym_embedding = generate_embedding(tail_hypernym, model, tokenizer)
    head_type_embedding = generate_embedding(head_type, model, tokenizer)
    tail_type_embedding = generate_embedding(tail_type, model, tokenizer)
    
    # Generate semantic role embeddings for head and tail
    head_role = f"subject of {head_type} that {head_hypernym}"
    tail_role = f"object of {tail_type} that {tail_hypernym}"
    head_role_embedding = generate_embedding(head_role, model, tokenizer)
    tail_role_embedding = generate_embedding(tail_role, model, tokenizer)
    
    # Create context vector from description
    context_embedding = generate_embedding(f"relationship between {head_type} and {tail_type}", model, tokenizer)
    
    # Compare with each unseen relation label
    for label in unseen_labels:
        # Generate embeddings for label and its variations
        label_embedding = generate_embedding(label, model, tokenizer)
        label_context = generate_embedding(f"relation {label} between {head_type} and {tail_type}", model, tokenizer)
        
        # Calculate base similarities
        description_similarity = cosine_similarity(label_embedding.numpy(), description_embedding.numpy())
        head_hypernym_similarity = cosine_similarity(label_embedding.numpy(), head_hypernym_embedding.numpy())
        tail_hypernym_similarity = cosine_similarity(label_embedding.numpy(), tail_hypernym_embedding.numpy())
        head_type_similarity = cosine_similarity(label_embedding.numpy(), head_type_embedding.numpy())
        tail_type_similarity = cosine_similarity(label_embedding.numpy(), tail_type_embedding.numpy())
        
        # Calculate semantic role similarities
        head_role_similarity = cosine_similarity(label_context.numpy(), head_role_embedding.numpy())
        tail_role_similarity = cosine_similarity(label_context.numpy(), tail_role_embedding.numpy())
        
        # Calculate context similarity
        context_similarity = cosine_similarity(label_context.numpy(), context_embedding.numpy())
        
        # Dynamic weight calculation based on context similarity
        context_weight = (1 + context_similarity) / 2  # Normalize to 0.5-1.0 range
        
        # Calculate semantic compatibility
        semantic_score = (head_role_similarity + tail_role_similarity) / 2
        
        # Calculate confidence based on consistency
        confidence = calculate_confidence([
            description_similarity,
            head_hypernym_similarity,
            tail_hypernym_similarity,
            head_type_similarity,
            tail_type_similarity,
            head_role_similarity,
            tail_role_similarity
        ])
        
        # Final weighted score with dynamic weighting
        total_score = (
            (0.4 * context_weight * description_similarity) +
            (0.1 * head_hypernym_similarity) +
            (0.1 * tail_hypernym_similarity) +
            (0.1 * head_type_similarity) +
            (0.1 * tail_type_similarity) +
            (0.2 * semantic_score)
        ) * confidence
        
        unseen_scores.append((label, total_score))
    
    # Sort by total score and return top predictions with confidence
    sorted_predictions = sorted(unseen_scores, key=lambda x: x[1], reverse=True)
    return sorted_predictions

# %% [markdown]
# ### The Below Cell to Test Only Unseen Relation Label

# %%
# %%time
matching = []
not_matching = []
the_predicted = []
the_actual = []
print(len(data_to_test))
for idx in range(len(data_to_test)):
    # if confidence < threshold:
        # Get descriptions for both entities
    item = data_to_test[idx]
    head = item['head_side_information']
    tail = item['tail_side_information']

    unseen_relation = predict_unseen_relation(
        head, tail, bert_model, tokenizer, unseen_relation_labels
    )
    
    # print(f"Unseen relation predicted for {head} -> {tail}: {unseen_relation[0]} with score {unseen_relation[1]}")
    if unseen_relation[0][0] == item['relation']:
        print(f"Matching: {idx}")
        matching.append({"data": item, "unseen_relation_with_score": unseen_relation})
    else:
        not_matching.append({"data": item, "unseen_relation_with_score": unseen_relation})
    the_predicted.append(unseen_relation[0])
    the_actual.append(item['relation'])
# Out:
# 1040
# Matching: 55
# Matching: 65
# Matching: 95
# Matching: 97
# Matching: 100
# Matching: 107
# Matching: 120
# Matching: 133
# Matching: 157
# Matching: 158
# Matching: 160
# Matching: 162
# Matching: 163
# Matching: 164
# Matching: 171
# Matching: 190
# Matching: 191
# Matching: 206
# Matching: 207
# Matching: 208
# Matching: 213
# Matching: 215
# Matching: 222
# Matching: 224
# Matching: 225
# Matching: 233
# Matching: 238
# Matching: 241
# Matching: 277
# Matching: 278
# Matching: 293
# Matching: 294
# Matching: 314
# Matching: 352
# Matching: 367
# Matching: 368
# Matching: 369
# Matching: 371
# Matching: 388
# Matching: 402
# Matching: 403
# Matching: 457
# Matching: 458
# Matching: 459
# Matching: 464
# Matching: 481
# Matching: 482
# Matching: 486
# Matching: 487
# Matching: 490
# Matching: 491
# Matching: 503
# Matching: 504
# Matching: 507
# Matching: 508
# Matching: 509
# Matching: 513
# Matching: 521
# Matching: 523
# Matching: 524
# Matching: 525
# Matching: 526
# Matching: 527
# Matching: 530
# Matching: 531
# Matching: 534
# Matching: 548
# Matching: 566
# Matching: 584
# Matching: 589
# Matching: 590
# Matching: 598
# Matching: 600
# Matching: 601
# Matching: 602
# Matching: 615
# Matching: 616
# Matching: 633
# Matching: 634
# Matching: 636
# Matching: 642
# Matching: 649
# Matching: 652
# Matching: 658
# Matching: 676
# Matching: 679
# Matching: 685
# Matching: 690
# Matching: 694
# Matching: 730
# Matching: 735
# Matching: 764
# Matching: 766
# Matching: 780
# Matching: 782
# Matching: 783
# Matching: 789
# Matching: 817
# Matching: 830
# Matching: 833
# Matching: 834
# Matching: 859
# Matching: 863
# Matching: 865
# Matching: 897
# Matching: 927
# Matching: 928
# Matching: 938
# Matching: 952
# Matching: 966
# Matching: 967
# Matching: 979
# Matching: 980
# Matching: 981
# Matching: 984
# Matching: 989
# Matching: 990
# Matching: 1036
# CPU times: total: 33min 38s
# Wall time: 5min 39s

# %% [markdown]
# # Evaluation

# %%
unseen_relation_labels_to_int = {unseen_relation_labels[index]:index for index in range(len(unseen_relation_labels))}

# %%
the_predicted_mapped_to_int = [unseen_relation_labels_to_int[item[0]] for item in the_predicted]
the_actual_mapped_to_int = [unseen_relation_labels_to_int[item] for item in the_actual]

# %%
print("Matched Unseen Relation Label Count:", len(set([item[0] for item in the_predicted])))
print("All Unseen Relation Label Count:",len(set(the_actual)))
print("All Unseen Relation Label:", unseen_relation_labels)
print("Matched Unseen Relation Label:", set([item[0] for item in the_predicted]))
print("All Unseen Relation Label with Count:", Counter(the_actual))
print("Predicted Unseen Relation Label with Count:", Counter([item[0] for item in the_predicted]))
print("Total Instance that Has Unseen Label", len(data_to_test))
print("Total Instance that Matching", len(matching))

micro_precision,micro_recall,micro_f1_score = eval.compute_micro_PRF(np.asarray(the_predicted_mapped_to_int, dtype=np.float32), np.asarray(the_actual_mapped_to_int, dtype=np.float32))
macro_precision,macro_recall,macro_f1_score = eval.compute_macro_PRF(np.asarray(the_predicted_mapped_to_int, dtype=np.float32), np.asarray(the_actual_mapped_to_int, dtype=np.float32))


print("macro_f1_score", macro_f1_score)
print("micro_f1_score", micro_f1_score)
print("macro_precision", macro_precision)
print("micro_precision", micro_precision)
print("macro_recall", macro_recall)
print("micro_recall", micro_recall)
# Out:
# Matched Unseen Relation Label Count: 3
# All Unseen Relation Label Count: 5
# All Unseen Relation Label: ['given name', 'capital of', 'operator', 'director / manager', 'country of citizenship']
# Predicted Unseen Relation Label: {'director / manager', 'country of citizenship', 'capital of'}
# All Unseen Relation Label with Count: Counter({'given name': 761, 'director / manager': 128, 'capital of': 102, 'country of citizenship': 41, 'operator': 8})
# Predicted Unseen Relation Label with Count: Counter({'country of citizenship': 549, 'director / manager': 490, 'capital of': 1})
# Total Instance that Has Unseen Label 1040
# Total Instance that Matching 118
# macro_f1_score 0.38794702306426976
# micro_f1_score 0.11346153846153845
# weighted_f1_score 0.039772249718357994
# macro_precision 0.41051262034868596
# micro_precision 0.11346153846153846
# weighted_precision 0.12154551732420585
# macro_recall 0.3677329925872788
# micro_recall 0.11346153846153846
# weighted_recall 0.11346153846153846
# acc 0.11346153846153846

# %%
print(len(set(the_predicted)))
print(len(set(the_actual)))
print(unseen_relation_labels)
print(set(the_predicted))
print(Counter(the_actual))
print(Counter(the_predicted))

print("macro_f1_score", macro_f1_score)
print("micro_f1_score", micro_f1_score)
print("weighted_f1_score", weighted_f1_score)
print("macro_precision", macro_precision)
print("micro_precision", micro_precision)
print("weighted_precision", weighted_precision)
print("macro_recall", macro_recall)
print("micro_recall", micro_recall)
print("weighted_recall", weighted_recall)
print("acc", acc)
# Out:
# 4
# 15
# ['investor', 'ethnic group', 'league', 'mother', 'diplomatic relation', 'part of', 'organizer', 'operator', 'spouse', 'child', 'coach of sports team', 'product or material produced', 'founded by', 'manufacturer', 'sibling']
# {'coach of sports team', 'product or material produced', 'diplomatic relation', 'organizer'}
# Counter({'ethnic group': 19, 'organizer': 19, 'coach of sports team': 19, 'part of': 19, 'child': 19, 'manufacturer': 18, 'diplomatic relation': 17, 'spouse': 12, 'league': 12, 'mother': 11, 'founded by': 10, 'sibling': 9, 'product or material produced': 8, 'investor': 8, 'operator': 8})
# Counter({'coach of sports team': 154, 'product or material produced': 32, 'diplomatic relation': 21, 'organizer': 1})
# macro_f1_score 0.08394179089341852
# micro_f1_score 0.18269230769230768
# weighted_f1_score 0.09949261075097704
# macro_precision 0.12876082251082252
# micro_precision 0.18269230769230768
# weighted_precision 0.164601023976024
# macro_recall 0.15399896800825594
# micro_recall 0.18269230769230768
# weighted_recall 0.18269230769230768
# acc 0.18269230769230768

# %%
print(classification_report(the_actual_mapped_to_int, the_predicted_mapped_to_int))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.00      0.00      0.00        19
#            2       0.00      0.00      0.00        12
#            3       0.00      0.00      0.00        11
#            4       0.71      0.88      0.79        17
#            5       0.00      0.00      0.00        19
#            6       1.00      0.05      0.10        19
#            7       0.00      0.00      0.00         8
#            8       0.00      0.00      0.00        12
#            9       0.00      0.00      0.00        19
#           10       0.12      1.00      0.22        19
#           11       0.09      0.38      0.15         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00        18
#           14       0.00      0.00      0.00         9
#
#     accuracy                           0.18       208
#    macro avg       0.13      0.15      0.08       208
# weighted avg       0.16      0.18      0.10       208
# C:\Users\mcha0133\Desktop\Dynamic Relation Extraction (DRE)\My Solution\pykeen_only\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mcha0133\Desktop\Dynamic Relation Extraction (DRE)\My Solution\pykeen_only\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mcha0133\Desktop\Dynamic Relation Extraction (DRE)\My Solution\pykeen_only\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
eval.compute_macro_PRF(np.asarray(the_predicted_mapped_to_int, dtype=np.float32), np.asarray(the_actual_mapped_to_int, dtype=np.float32))
# Out:
# (0.48285308441558444, 0.16499889429455994, 0.2459519385706299)

# %%
eval.compute_micro_PRF(np.asarray(the_predicted_mapped_to_int, dtype=np.float32), np.asarray(the_actual_mapped_to_int, dtype=np.float32))
# Out:
# (0.18269230769230768, 0.18269230769230768, 0.18269230769230765)
